# %% [markdown]
# <a href="https://colab.research.google.com/github/adi-devv/NuFu-Archive/blob/main/src/LaserProton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Load
data_path = '/content/drive/MyDrive/Colab_Projects/laserProton/fuchs_v3-2_seed-5_points_25000_noise_0.csv'
df = pd.read_csv(data_path)

# Display sample
print("Raw Data Sample:")
print(df.head())

# 80/20 split
train_size = int(0.8 * len(df))  # 20,000 for training, 5,000 for testing
train_df = df.iloc[:train_size].copy()
test_df = df.iloc[train_size:].copy()

# Logarithmic Transformation
log_transform_cols = ["Intensity_(W_cm2)", "Max_Proton_Energy_(MeV)",
                     "Total_Proton_Energy_(MeV)", "Avg_Proton_Energy_(MeV)"]

for col in log_transform_cols:
    train_df[f"log_{col}"] = np.log(train_df[col])
    test_df[f"log_{col}"] = np.log(test_df[col])

# Z-Score Normalization
scaler = StandardScaler()
features_to_normalize = [f"log_{col}" for col in log_transform_cols] + ["Focal_Distance_(um)", "Target_Thickness (um)"]

scaler.fit(train_df[features_to_normalize])

train_df[features_to_normalize] = scaler.transform(train_df[features_to_normalize])
test_df[features_to_normalize] = scaler.transform(test_df[features_to_normalize])

# Retain original columns for reference or post-processing
original_cols = [col for col in df.columns if col not in features_to_normalize]
train_df = pd.concat([train_df, df.iloc[:train_size][original_cols]], axis=1)
test_df = pd.concat([test_df, df.iloc[train_size:][original_cols]], axis=1)

x_train = train_df[features_to_normalize].values
y_train = train_df[[f"log_{col}" for col in log_transform_cols]].values
x_test = test_df[features_to_normalize].values
y_test = test_df[[f"log_{col}" for col in log_transform_cols]].values

# Display processed data sample
# print("\nPreprocessed Training Data Sample:")
# print(train_df.head())

# Save to Google Drive
train_df.to_csv('/content/drive/MyDrive/Colab_Projects/laserProton/preprocessed_train_data_noise0.csv', index=False)
test_df.to_csv('/content/drive/MyDrive/Colab_Projects/laserProton/preprocessed_test_data_noise0.csv', index=False)
print("Preprocessed data saved to /content/drive/MyDrive/Colab_Projects/laserProton/")
# Out:
# Raw Data Sample:
#    Avg_Proton_Energy_(MeV)  Avg_Proton_Energy_Exact_(MeV)  \
# 0                 0.007261                       0.007261
# 1                 0.119684                       0.119684
# 2                 0.016739                       0.016739
# 3                 0.186123                       0.186123
# 4                 0.048987                       0.048987
#
#    Focal_Distance_(um)  Intensity_(W_cm2)  Max_Proton_Energy_(MeV)  \
# 0             1.181257       1.667221e+18                 0.025138
# 1            -7.518057       7.425613e+18                 0.597101
# 2             3.919023       1.609604e+18                 0.065116
# 3             4.824679       8.291076e+18                 0.984354
# 4             1.102200       3.079011e+18                 0.204535
#
#    Max_Proton_Energy_Exact_(MeV)  Pulse_Duration_(fs)  Spot_Size_(FWHM um)  \
# 0                       0.025138                 40.0                  1.5
# 1                       0.597101                 40.0                  1.5
# 2                       0.065116                 40.0                  1.5
# 3                       0.984354                 40.0                  1.5
# 4                       0.204535                 40.0                  1.5
#
#    Target_Thickness (um)  Total_Proton_Energy_(MeV)  \
# 0               4.502523               5.173814e+05
# 1               1.048708               1.025344e+08
# 2               1.475977               1.591224e+06
# 3               1.117933               2.117825e+08
# 4               1.752827               1.299223e+07
#
#    Total_Proton_Energy_Exact_(MeV)  laser_E(mJ)  ratio_proE_laserE_
# 0                     5.173814e+05     2.356978            0.000035
# 1                     1.025344e+08    10.497713            0.001563
# 2                     1.591224e+06     2.275525            0.000112
# 3                     2.117825e+08    11.721233            0.002891
# 4                     1.299223e+07     4.352849            0.000478
# Preprocessed data saved to /content/drive/MyDrive/Colab_Projects/laserProton/

# %%
# !pip install cuml-cu11 --extra-index-url=https://pypi.nvidia.com
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.nvidia.com
# Collecting cuml-cu11
#   Downloading https://pypi.nvidia.com/cuml-cu11/cuml_cu11-25.6.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (8.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 69.3 MB/s eta 0:00:00
# Collecting cuda-python<12.0a0,>=11.8.5 (from cuml-cu11)
#   Downloading cuda_python-11.8.7-py3-none-any.whl.metadata (14 kB)
# Collecting cudf-cu11==25.6.* (from cuml-cu11)
#   Downloading https://pypi.nvidia.com/cudf-cu11/cudf_cu11-25.6.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 272.8 MB/s eta 0:00:00
# Collecting cupy-cuda11x>=12.0.0 (from cuml-cu11)
#   Downloading cupy_cuda11x-13.6.0-cp312-cp312-manylinux2014_x86_64.whl.metadata (2.4 kB)
# Collecting cuvs-cu11==25.6.* (from cuml-cu11)
#   Downloading https://pypi.nvidia.com/cuvs-cu11/cuvs_cu11-25.6.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (832 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 832.7/832.7 kB 281.7 MB/s eta 0:00:00
# Requirement already satisfied: dask-cuda==25.6.* in /usr/local/lib/python3.12/dist-packages (from cuml-cu11) (25.6.0)
# Collecting dask-cudf-cu11==25.6.* (from cuml-cu11)
#   Downloading https://pypi.nvidia.com/dask-cudf-cu11/dask_cudf_cu11-25.6.0-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 103.1 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.12/dist-packages (from cuml-cu11) (1.5.2)
# Collecting libcuml-cu11==25.6.* (from cuml-cu11)
#   Downloading https://pypi.nvidia.com/libcuml-cu11/libcuml_cu11-25.6.0-py3-none-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (139.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 MB 93.3 MB/s eta 0:00:00
# Requirement already satisfied: numba<0.62.0a0,>=0.59.1 in /usr/local/lib/python3.12/dist-packages (from cuml-cu11) (0.60.0)
# Requirement already satisfied: numpy<3.0a0,>=1.23 in /usr/local/lib/python3.12/dist-packages (from cuml-cu11) (2.0.2)
# Collecting nvidia-cublas-cu11 (from cuml-cu11)
#   Downloading nvidia_cublas_cu11-11.11.3.6-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu11 (from cuml-cu11)
#   Downloading https://pypi.nvidia.com/nvidia-cufft-cu11/nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux2014_x86_64.whl (168.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 138.3 MB/s eta 0:00:00
# Collecting nvidia-curand-cu11 (from cuml-cu11)
#   Downloading https://pypi.nvidia.com/nvidia-curand-cu11/nvidia_curand_cu11-10.3.0.86-py3-none-manylinux2014_x86_64.whl (58.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 MB 154.0 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu11 (from cuml-cu11)
#   Downloading https://pypi.nvidia.com/nvidia-cusolver-cu11/nvidia_cusolver_cu11-11.4.1.48-py3-none-manylinux2014_x86_64.whl (128.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 MB 131.0 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu11 (from cuml-cu11)
#   Downloading https://pypi.nvidia.com/nvidia-cusparse-cu11/nvidia_cusparse_cu11-11.7.5.86-py3-none-manylinux2014_x86_64.whl (204.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.1/204.1 MB 116.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from cuml-cu11) (25.0)
# Collecting pylibraft-cu11==25.6.* (from cuml-cu11)
#   Downloading https://pypi.nvidia.com/pylibraft-cu11/pylibraft_cu11-25.6.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (855 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 855.0/855.0 kB 197.4 MB/s eta 0:00:00
# Collecting raft-dask-cu11==25.6.* (from cuml-cu11)
#   Downloading https://pypi.nvidia.com/raft-dask-cu11/raft_dask_cu11-25.6.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (318.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.5/318.5 MB 124.0 MB/s eta 0:00:00
# Requirement already satisfied: rapids-dask-dependency==25.6.* in /usr/local/lib/python3.12/dist-packages (from cuml-cu11) (25.6.0)
# Collecting rmm-cu11==25.6.* (from cuml-cu11)
#   Downloading https://pypi.nvidia.com/rmm-cu11/rmm_cu11-25.6.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 273.0 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=1.5 in /usr/local/lib/python3.12/dist-packages (from cuml-cu11) (1.6.1)
# Requirement already satisfied: scipy>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from cuml-cu11) (1.16.2)
# Requirement already satisfied: treelite==4.4.1 in /usr/local/lib/python3.12/dist-packages (from cuml-cu11) (4.4.1)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.12/dist-packages (from cudf-cu11==25.6.*->cuml-cu11) (5.5.2)
# Collecting cubinlinker-cu11 (from cudf-cu11==25.6.*->cuml-cu11)
#   Downloading https://pypi.nvidia.com/cubinlinker-cu11/cubinlinker_cu11-0.3.0.post3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (8.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 221.0 MB/s eta 0:00:00
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from cudf-cu11==25.6.*->cuml-cu11) (2025.3.0)
# Collecting libcudf-cu11==25.6.* (from cudf-cu11==25.6.*->cuml-cu11)
#   Downloading https://pypi.nvidia.com/libcudf-cu11/libcudf_cu11-25.6.0-py3-none-manylinux_2_28_x86_64.whl (445.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 445.9/445.9 MB 57.5 MB/s eta 0:00:00
# Requirement already satisfied: numba-cuda<0.12.0a0,>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from cudf-cu11==25.6.*->cuml-cu11) (0.11.0)
# Requirement already satisfied: nvtx>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from cudf-cu11==25.6.*->cuml-cu11) (0.2.13)
# Requirement already satisfied: pandas<2.2.4dev0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from cudf-cu11==25.6.*->cuml-cu11) (2.2.2)
# Collecting ptxcompiler-cu11 (from cudf-cu11==25.6.*->cuml-cu11)
#   Downloading https://pypi.nvidia.com/ptxcompiler-cu11/ptxcompiler_cu11-0.8.1.post3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (8.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 202.2 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow<20.0.0a0,>=14.0.0 in /usr/local/lib/python3.12/dist-packages (from cudf-cu11==25.6.*->cuml-cu11) (18.1.0)
# Collecting pylibcudf-cu11==25.6.* (from cudf-cu11==25.6.*->cuml-cu11)
#   Downloading https://pypi.nvidia.com/pylibcudf-cu11/pylibcudf_cu11-25.6.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (27.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.7/27.7 MB 214.5 MB/s eta 0:00:00
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from cudf-cu11==25.6.*->cuml-cu11) (13.9.4)
# Requirement already satisfied: typing_extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from cudf-cu11==25.6.*->cuml-cu11) (4.15.0)
# Collecting libcuvs-cu11==25.6.* (from cuvs-cu11==25.6.*->cuml-cu11)
#   Downloading https://pypi.nvidia.com/libcuvs-cu11/libcuvs_cu11-25.6.1-py3-none-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (1039.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 GB 49.8 MB/s eta 0:00:00
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.12/dist-packages (from dask-cuda==25.6.*->cuml-cu11) (8.2.1)
# Requirement already satisfied: pynvml<13.0.0a0,>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from dask-cuda==25.6.*->cuml-cu11) (12.0.0)
# Requirement already satisfied: zict>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from dask-cuda==25.6.*->cuml-cu11) (3.0.0)
# Collecting libraft-cu11==25.6.* (from libcuml-cu11==25.6.*->cuml-cu11)
#   Downloading https://pypi.nvidia.com/libraft-cu11/libraft_cu11-25.6.0-py3-none-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (18.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.9/18.9 MB 205.2 MB/s eta 0:00:00
# Requirement already satisfied: rapids-logger==0.1.* in /usr/local/lib/python3.12/dist-packages (from libcuml-cu11==25.6.*->cuml-cu11) (0.1.1)
# Collecting distributed-ucxx-cu11==0.44.* (from raft-dask-cu11==25.6.*->cuml-cu11)
#   Downloading https://pypi.nvidia.com/distributed-ucxx-cu11/distributed_ucxx_cu11-0.44.0-py3-none-any.whl (25 kB)
# Collecting ucx-py-cu11==0.44.* (from raft-dask-cu11==25.6.*->cuml-cu11)
#   Downloading https://pypi.nvidia.com/ucx-py-cu11/ucx_py_cu11-0.44.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 259.2 MB/s eta 0:00:00
# Requirement already satisfied: dask==2025.5.0 in /usr/local/lib/python3.12/dist-packages (from rapids-dask-dependency==25.6.*->cuml-cu11) (2025.5.0)
# Requirement already satisfied: distributed==2025.5.0 in /usr/local/lib/python3.12/dist-packages (from rapids-dask-dependency==25.6.*->cuml-cu11) (2025.5.0)
# Collecting librmm-cu11==25.6.* (from rmm-cu11==25.6.*->cuml-cu11)
#   Downloading https://pypi.nvidia.com/librmm-cu11/librmm_cu11-25.6.0-py3-none-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 248.4 MB/s eta 0:00:00
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from dask==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11) (3.1.1)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from dask==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from dask==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from dask==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11) (0.12.1)
# Requirement already satisfied: jinja2>=2.10.3 in /usr/local/lib/python3.12/dist-packages (from distributed==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11) (3.1.6)
# Requirement already satisfied: locket>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from distributed==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from distributed==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11) (1.1.1)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from distributed==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11) (5.9.5)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /usr/local/lib/python3.12/dist-packages (from distributed==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from distributed==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11) (3.1.0)
# Requirement already satisfied: tornado>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from distributed==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11) (6.4.2)
# Requirement already satisfied: urllib3>=1.26.5 in /usr/local/lib/python3.12/dist-packages (from distributed==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11) (2.5.0)
# Collecting ucxx-cu11==0.44.* (from distributed-ucxx-cu11==0.44.*->raft-dask-cu11==25.6.*->cuml-cu11)
#   Downloading https://pypi.nvidia.com/ucxx-cu11/ucxx_cu11-0.44.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (681 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 681.9/681.9 kB 231.9 MB/s eta 0:00:00
# Collecting libkvikio-cu11==25.6.* (from libcudf-cu11==25.6.*->cudf-cu11==25.6.*->cuml-cu11)
#   Downloading https://pypi.nvidia.com/libkvikio-cu11/libkvikio_cu11-25.6.0-py3-none-manylinux_2_28_x86_64.whl (58.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.6/58.6 MB 116.6 MB/s eta 0:00:00
# Collecting libucx-cu11<1.19,>=1.15.0 (from ucx-py-cu11==0.44.*->raft-dask-cu11==25.6.*->cuml-cu11)
#   Downloading libucx_cu11-1.18.1-py3-none-manylinux_2_28_x86_64.whl.metadata (2.9 kB)
# Collecting libucxx-cu11==0.44.* (from ucxx-cu11==0.44.*->distributed-ucxx-cu11==0.44.*->raft-dask-cu11==25.6.*->cuml-cu11)
#   Downloading https://pypi.nvidia.com/libucxx-cu11/libucxx_cu11-0.44.0-py3-none-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (507 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.5/507.5 kB 255.0 MB/s eta 0:00:00
# Collecting cuda-bindings~=11.8.7 (from cuda-python<12.0a0,>=11.8.5->cuml-cu11)
#   Downloading cuda_bindings-11.8.7-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: fastrlock>=0.5 in /usr/local/lib/python3.12/dist-packages (from cupy-cuda11x>=12.0.0->cuml-cu11) (0.8.3)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba<0.62.0a0,>=0.59.1->cuml-cu11) (0.43.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.5->cuml-cu11) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<2.2.4dev0,>=2.0->cudf-cu11==25.6.*->cuml-cu11) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<2.2.4dev0,>=2.0->cudf-cu11==25.6.*->cuml-cu11) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<2.2.4dev0,>=2.0->cudf-cu11==25.6.*->cuml-cu11) (2025.2)
# Requirement already satisfied: nvidia-ml-py<13.0.0a0,>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from pynvml<13.0.0a0,>=12.0.0->dask-cuda==25.6.*->cuml-cu11) (12.575.51)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->cudf-cu11==25.6.*->cuml-cu11) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->cudf-cu11==25.6.*->cuml-cu11) (2.19.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=2.10.3->distributed==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11) (3.0.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->cudf-cu11==25.6.*->cuml-cu11) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<2.2.4dev0,>=2.0->cudf-cu11==25.6.*->cuml-cu11) (1.17.0)
# Downloading cuda_python-11.8.7-py3-none-any.whl (11 kB)
# Downloading cupy_cuda11x-13.6.0-cp312-cp312-manylinux2014_x86_64.whl (99.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.7/99.7 MB 9.0 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu11-11.11.3.6-py3-none-manylinux2014_x86_64.whl (417.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.9/417.9 MB 1.3 MB/s eta 0:00:00
# Downloading cuda_bindings-11.8.7-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 13.9 MB/s eta 0:00:00
# Downloading libucx_cu11-1.18.1-py3-none-manylinux_2_28_x86_64.whl (27.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.6/27.6 MB 48.0 MB/s eta 0:00:00
# Installing collected packages: ptxcompiler-cu11, libkvikio-cu11, cuda-bindings, nvidia-cusparse-cu11, nvidia-curand-cu11, nvidia-cufft-cu11, nvidia-cublas-cu11, libucx-cu11, librmm-cu11, cupy-cuda11x, cuda-python, cubinlinker-cu11, ucx-py-cu11, rmm-cu11, nvidia-cusolver-cu11, libucxx-cu11, libcudf-cu11, ucxx-cu11, pylibcudf-cu11, libraft-cu11, pylibraft-cu11, libcuvs-cu11, cudf-cu11, libcuml-cu11, distributed-ucxx-cu11, dask-cudf-cu11, cuvs-cu11, raft-dask-cu11, cuml-cu11
#   Attempting uninstall: cuda-python
#     Found existing installation: cuda-python 12.6.2.post1
#     Uninstalling cuda-python-12.6.2.post1:
#       Successfully uninstalled cuda-python-12.6.2.post1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pylibcudf-cu12 25.6.0 requires cuda-python<13.0a0,>=12.6.2, but you have cuda-python 11.8.7 which is incompatible.
# rmm-cu12 25.6.0 requires cuda-python<13.0a0,>=12.6.2, but you have cuda-python 11.8.7 which is incompatible.
# cuvs-cu12 25.6.1 requires cuda-python<13.0a0,>=12.6.2, but you have cuda-python 11.8.7 which is incompatible.
# cuml-cu12 25.6.0 requires cuda-python<13.0a0,>=12.6.2, but you have cuda-python 11.8.7 which is incompatible.
# cudf-cu12 25.6.0 requires cuda-python<13.0a0,>=12.6.2, but you have cuda-python 11.8.7 which is incompatible.
# pylibraft-cu12 25.6.0 requires cuda-python<13.0a0,>=12.6.2, but you have cuda-python 11.8.7 which is incompatible.
# Successfully installed cubinlinker-cu11-0.3.0.post3 cuda-bindings-11.8.7 cuda-python-11.8.7 cudf-cu11-25.6.0 cuml-cu11-25.6.0 cupy-cuda11x-13.6.0 cuvs-cu11-25.6.1 dask-cudf-cu11-25.6.0 distributed-ucxx-cu11-0.44.0 libcudf-cu11-25.6.0 libcuml-cu11-25.6.0 libcuvs-cu11-25.6.1 libkvikio-cu11-25.6.0 libraft-cu11-25.6.0 librmm-cu11-25.6.0 libucx-cu11-1.18.1 libucxx-cu11-0.44.0 nvidia-cublas-cu11-11.11.3.6 nvidia-cufft-cu11-10.9.0.58 nvidia-curand-cu11-10.3.0.86 nvidia-cusolver-cu11-11.4.1.48 nvidia-cusparse-cu11-11.7.5.86 ptxcompiler-cu11-0.8.1.post3 pylibcudf-cu11-25.6.0 pylibraft-cu11-25.6.0 raft-dask-cu11-25.6.0 rmm-cu11-25.6.0 ucx-py-cu11-0.44.0 ucxx-cu11-0.44.0

# %%
# Import necessary libraries (cuml for SVR)
from cuml.svm import SVR
import numpy as np
import pandas as pd

# Quick check to ensure variables are defined from previous cell
print(f"x_train shape: {x_train.shape}, y_train shape: {y_train.shape}")
assert x_train is not None and y_train is not None, "Variables not defined from previous cell!"

# Investigate unexpected y_train shape
print("y_train columns:", train_df.columns[train_df.columns.str.startswith('log_')])
target_cols = ["log_Max_Proton_Energy_(MeV)", "log_Total_Proton_Energy_(MeV)", "log_Avg_Proton_Energy_(MeV)"]
if y_train.shape[1] > len(target_cols):
    print(f"Warning: y_train has {y_train.shape[1]} columns, using first {len(target_cols)} for training.")
    y_train = y_train[:, :len(target_cols)]

try:
    # Train separate SVR models for each target
    models = {}
    for i, target in enumerate(target_cols):
        model = SVR(kernel='rbf', C=2.5, epsilon=0.01, tol=0.001)  # Per Section 3.1
        model.fit(x_train, y_train[:, i])
        models[target] = model
        print(f"Trained model for {target}")

    # Make predictions
    predictions = {}
    for target, model in models.items():
        predictions[target] = model.predict(x_train)  # Using x_train for consistency with fit

    # Detransform and apply bias correction
    training_output_means = {
        "Max_Proton_Energy_(MeV)": train_df["Max_Proton_Energy_(MeV)"].mean(),
        "Total_Proton_Energy_(MeV)": train_df["Total_Proton_Energy_(MeV)"].mean(),
        "Avg_Proton_Energy_(MeV)": train_df["Avg_Proton_Energy_(MeV)"].mean()
    }

    def apply_bias_correction(predictions, training_means, feature_name):
        detransformed_preds = np.exp(predictions)
        mean_detransformed = detransformed_preds.mean()
        correction_factor = training_means[feature_name] / mean_detransformed
        return detransformed_preds * correction_factor

    corrected_predictions = {}
    for target, pred in predictions.items():
        base_target = target.replace("log_", "")
        corrected_predictions[base_target] = apply_bias_correction(pred, training_output_means, base_target)

    # Evaluate MAPE
    exact_values = {
        "Max_Proton_Energy_(MeV)": test_df["Max_Proton_Energy_Exact_(MeV)"].values,
        "Total_Proton_Energy_(MeV)": test_df["Total_Proton_Energy_Exact_(MeV)"].values,
        "Avg_Proton_Energy_(MeV)": test_df["Avg_Proton_Energy_Exact_(MeV)"].values
    }

    for target in corrected_predictions:
        mape = np.mean(np.abs((corrected_predictions[target] - exact_values[target]) / exact_values[target])) * 100
        print(f"MAPE for {target}: {mape:.2f}%")

    # Save predictions to Drive
    results_df = pd.DataFrame(corrected_predictions)
    results_df.to_csv('/content/drive/MyDrive/Colab_Projects/laserProton/predictions_noise0.csv', index=False)
    print("Predictions saved to /content/drive/MyDrive/Colab_Projects/laserProton/predictions_noise0.csv")

except Exception as e:
    print(f"Error occurred: {e}")
    print("Ensure cuml is installed: !pip install cuml-cu11 --extra-index-url=https://pypi.nvidia.com")
# Out:
# x_train shape: (20000, 6), y_train shape: (20000, 3)
# y_train columns: Index(['log_Intensity_(W_cm2)', 'log_Max_Proton_Energy_(MeV)',
#        'log_Total_Proton_Energy_(MeV)', 'log_Avg_Proton_Energy_(MeV)'],
#       dtype='object')
# Trained model for log_Max_Proton_Energy_(MeV)
# Trained model for log_Total_Proton_Energy_(MeV)
# Trained model for log_Avg_Proton_Energy_(MeV)
# Error occurred: operands could not be broadcast together with shapes (5000,) (2,)
# Ensure cuml is installed: !pip install cuml-cu11 --extra-index-url=https://pypi.nvidia.com
